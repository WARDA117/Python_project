# %%
# !pip install pandas

# %%
import pandas as pd

# %%
import os
print(os.getcwd())
# Out:
# c:\COVID-19  drug discovery dataset\Data_handling

# %%
import pandas as pd
# call dataset # assign name
df = pd.read_csv("master_results_table.csv") 
df2 =pd.read_csv("mers_results.csv")
df3 = pd.read_csv("sars_results.csv")

# %%
df
# Out:
#         id  gen                                              smile     source  \
# 0     AAAA    0         COc1cccc(NC(=O)Cc2ccc(NC(=O)N3CCCC3)cc2)c1  generated
# 1     AAAB    0          C=CCNC(=O)CNc1cccc(C(=O)N(C)CCc2ccccc2)c1  generated
# 2     AAAC    0          CC(=O)Nc1ccc(S(=O)(=O)Nc2ccc(C)c(C)c2)cc1   training
# 3     AAAD    0      CCOC(=O)C1=C(C(=O)OCC)C(c2cccc(Cl)c2)NC(=O)N1  generated
# 4     AAAE    0  NC(=O)c1ccc(NC(=O)C(CC(=O)O)NC(=O)c2cc(-c3cccc...  generated
# ...    ...  ...                                                ...        ...
# 1172  ABTC    0  CCCC1(CCc2ccccc2)CC(O)=C(C(CC)c2cccc(NS(=O)(=O...     manual
# 1173  ABTD    0           O=C1Nc2ccc(Cl)cc2C(C#CC2CC2)(C(F)(F)F)O1     manual
# 1174  ABTE    0  CC(C)(C)NC(=O)C1CN(Cc2cccnc2)CCN1CC(O)CC(Cc1cc...     manual
# 1175  ABTF    0  CCOP(=O)(COc1ccc(CC(NC(=O)OC2COC3OCCC23)C(O)CN...     manual
# 1176  ABTG    0  COC(=O)NC(C(=O)NCCCCC(CO)N(CC(C)C)S(=O)(=O)c1c...     manual
#
#       score
# 0      99.9
# ...

# %%
df2
# Out:
#                                    Unnamed: 0  Connectivity   P_value
# 0                               valproic acid     -0.376625  0.003320
# 1                                 flupentixol     -0.269090  0.003384
# 2                               syrosingopine     -0.318895  0.003397
# 3                             levomepromazine     -0.329905  0.003427
# 4                                 eucatropine     -0.288555  0.003468
# ...                                       ...           ...       ...
# 1283                                semustine      0.000000  1.000000
# 1284                                CP-944629      0.000000  1.000000
# 1285                               irinotecan      0.000000  1.000000
# 1286                                BCB000039      0.000000  1.000000
# 1287  11-deoxy-16,16-dimethylprostaglandin E2      0.000000  1.000000
#
# [1288 rows x 3 columns]

# %%
df3
# Out:
#                                    Unnamed: 0  Connectivity   P_value
# 0                               valproic acid     -0.376625  0.003243
# 1                                   rifabutin     -0.340380  0.003250
# 2                             levomepromazine     -0.329905  0.003363
# 3                                   promazine     -0.338460  0.003409
# 4                               Prestwick-559     -0.332285  0.003454
# ...                                       ...           ...       ...
# 1283                                semustine      0.000000  1.000000
# 1284                                CP-944629      0.000000  1.000000
# 1285                               irinotecan      0.000000  1.000000
# 1286                                BCB000039      0.000000  1.000000
# 1287  11-deoxy-16,16-dimethylprostaglandin E2      0.000000  1.000000
#
# [1288 rows x 3 columns]

# %%
# head # view first few rows
df.head()
# Out:
#      id  gen                                              smile     source  \
# 0  AAAA    0         COc1cccc(NC(=O)Cc2ccc(NC(=O)N3CCCC3)cc2)c1  generated
# 1  AAAB    0          C=CCNC(=O)CNc1cccc(C(=O)N(C)CCc2ccccc2)c1  generated
# 2  AAAC    0          CC(=O)Nc1ccc(S(=O)(=O)Nc2ccc(C)c(C)c2)cc1   training
# 3  AAAD    0      CCOC(=O)C1=C(C(=O)OCC)C(c2cccc(Cl)c2)NC(=O)N1  generated
# 4  AAAE    0  NC(=O)c1ccc(NC(=O)C(CC(=O)O)NC(=O)c2cc(-c3cccc...  generated
#
#    score
# 0   99.9
# 1   99.9
# 2   99.9
# 3   99.9
# 4   99.9

# %%
# head # view first few rows
df2.head()
# Out:
#         Unnamed: 0  Connectivity   P_value
# 0    valproic acid     -0.376625  0.003320
# 1      flupentixol     -0.269090  0.003384
# 2    syrosingopine     -0.318895  0.003397
# 3  levomepromazine     -0.329905  0.003427
# 4      eucatropine     -0.288555  0.003468

# %%
# head # view first few rows
df3.head()
# Out:
#         Unnamed: 0  Connectivity   P_value
# 0    valproic acid     -0.376625  0.003243
# 1        rifabutin     -0.340380  0.003250
# 2  levomepromazine     -0.329905  0.003363
# 3        promazine     -0.338460  0.003409
# 4    Prestwick-559     -0.332285  0.003454

# %%
#shape #attribute that returns the dataframe or series as tuples
df.shape
# Out:
# (1177, 5)

# %%
df2.shape
# Out:
# (1288, 3)

# %%
df3.shape
# Out:
# (1288, 3)

# %%
#info # a method use to display summary of dataframe
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1177 entries, 0 to 1176
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      1177 non-null   object
#  1   gen     1177 non-null   int64
#  2   smile   1177 non-null   object
#  3   source  1177 non-null   object
#  4   score   1177 non-null   float64
# dtypes: float64(1), int64(1), object(3)
# memory usage: 46.1+ KB

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1288 entries, 0 to 1287
# Data columns (total 3 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    1288 non-null   object
#  1   Connectivity  1288 non-null   float64
#  2   P_value       1288 non-null   float64
# dtypes: float64(2), object(1)
# memory usage: 30.3+ KB

# %%
df3.info
# Out:
# <bound method DataFrame.info of                                    Unnamed: 0  Connectivity   P_value
# 0                               valproic acid     -0.376625  0.003243
# 1                                   rifabutin     -0.340380  0.003250
# 2                             levomepromazine     -0.329905  0.003363
# 3                                   promazine     -0.338460  0.003409
# 4                               Prestwick-559     -0.332285  0.003454
# ...                                       ...           ...       ...
# 1283                                semustine      0.000000  1.000000
# 1284                                CP-944629      0.000000  1.000000
# 1285                               irinotecan      0.000000  1.000000
# 1286                                BCB000039      0.000000  1.000000
# 1287  11-deoxy-16,16-dimethylprostaglandin E2      0.000000  1.000000
#
# [1288 rows x 3 columns]>

# %%
# find null #missing or undefined value
df.isnull().sum()
# Out:
# id        0
# gen       0
# smile     0
# source    0
# score     0
# dtype: int64

# %%
df2.isnull().sum()
# Out:
# Unnamed: 0      0
# Connectivity    0
# P_value         0
# dtype: int64

# %%
df3.isnull().sum()
# Out:
# Unnamed: 0      0
# Connectivity    0
# P_value         0
# dtype: int64

# %%
#describe # a method decsribes statistics
df.describe()
# Out:
#           gen         score
# count  1177.0  1.177000e+03
# mean      0.0  9.990000e+01
# std       0.0  1.421690e-14
# min       0.0  9.990000e+01
# 25%       0.0  9.990000e+01
# 50%       0.0  9.990000e+01
# 75%       0.0  9.990000e+01
# max       0.0  9.990000e+01

# %%
df2.describe()
# Out:
#        Connectivity      P_value
# count   1288.000000  1288.000000
# mean      -0.045518     0.705153
# std        0.157044     0.385772
# min       -0.809330     0.003320
# 25%       -0.199497     0.311205
# 50%        0.000000     1.000000
# 75%        0.000000     1.000000
# max        0.723920     1.000000

# %%
df3.describe()
# Out:
#        Connectivity      P_value
# count   1288.000000  1288.000000
# mean      -0.045518     0.708410
# std        0.157044     0.384227
# min       -0.809330     0.003243
# 25%       -0.199497     0.312161
# 50%        0.000000     1.000000
# 75%        0.000000     1.000000
# max        0.723920     1.000000

# %%
#  drop duplicates
df=df.drop_duplicates()
df
# Out:
#         id  gen                                              smile     source  \
# 0     AAAA    0         COc1cccc(NC(=O)Cc2ccc(NC(=O)N3CCCC3)cc2)c1  generated
# 1     AAAB    0          C=CCNC(=O)CNc1cccc(C(=O)N(C)CCc2ccccc2)c1  generated
# 2     AAAC    0          CC(=O)Nc1ccc(S(=O)(=O)Nc2ccc(C)c(C)c2)cc1   training
# 3     AAAD    0      CCOC(=O)C1=C(C(=O)OCC)C(c2cccc(Cl)c2)NC(=O)N1  generated
# 4     AAAE    0  NC(=O)c1ccc(NC(=O)C(CC(=O)O)NC(=O)c2cc(-c3cccc...  generated
# ...    ...  ...                                                ...        ...
# 1172  ABTC    0  CCCC1(CCc2ccccc2)CC(O)=C(C(CC)c2cccc(NS(=O)(=O...     manual
# 1173  ABTD    0           O=C1Nc2ccc(Cl)cc2C(C#CC2CC2)(C(F)(F)F)O1     manual
# 1174  ABTE    0  CC(C)(C)NC(=O)C1CN(Cc2cccnc2)CCN1CC(O)CC(Cc1cc...     manual
# 1175  ABTF    0  CCOP(=O)(COc1ccc(CC(NC(=O)OC2COC3OCCC23)C(O)CN...     manual
# 1176  ABTG    0  COC(=O)NC(C(=O)NCCCCC(CO)N(CC(C)C)S(=O)(=O)c1c...     manual
#
#       score
# 0      99.9
# ...

# %%
df2=df2.drop_duplicates()
df2
# Out:
#                                    Unnamed: 0  Connectivity   P_value
# 0                               valproic acid     -0.376625  0.003320
# 1                                 flupentixol     -0.269090  0.003384
# 2                               syrosingopine     -0.318895  0.003397
# 3                             levomepromazine     -0.329905  0.003427
# 4                                 eucatropine     -0.288555  0.003468
# ...                                       ...           ...       ...
# 1283                                semustine      0.000000  1.000000
# 1284                                CP-944629      0.000000  1.000000
# 1285                               irinotecan      0.000000  1.000000
# 1286                                BCB000039      0.000000  1.000000
# 1287  11-deoxy-16,16-dimethylprostaglandin E2      0.000000  1.000000
#
# [1288 rows x 3 columns]

# %%
df3=df3.drop_duplicates()
df3
# Out:
#                                    Unnamed: 0  Connectivity   P_value
# 0                               valproic acid     -0.376625  0.003243
# 1                                   rifabutin     -0.340380  0.003250
# 2                             levomepromazine     -0.329905  0.003363
# 3                                   promazine     -0.338460  0.003409
# 4                               Prestwick-559     -0.332285  0.003454
# ...                                       ...           ...       ...
# 1283                                semustine      0.000000  1.000000
# 1284                                CP-944629      0.000000  1.000000
# 1285                               irinotecan      0.000000  1.000000
# 1286                                BCB000039      0.000000  1.000000
# 1287  11-deoxy-16,16-dimethylprostaglandin E2      0.000000  1.000000
#
# [1288 rows x 3 columns]

# %%
#mean # median # mode # score
print(df["score"].mean())
print(df["score"].median())
print(df["score"].mode())
# Out:
# 99.89999999999999
# 99.9
# 0    99.9
# Name: score, dtype: float64

# %%
#mean # median # mode # temperature
print(df2["Connectivity"].mean())
print(df2["Connectivity"].median())
print(df2["Connectivity"].mode())
# Out:
# -0.04551785714285715
# 0.0
# 0    0.0
# Name: Connectivity, dtype: float64

# %%
#mean # median # mode 
print(df2["P_value"].mean())
print(df2["P_value"].median())
print(df2["P_value"].mode())
# Out:
# 0.7051525055472477
# 1.0
# 0    1.0
# Name: P_value, dtype: float64

# %%
#mean # median # mode # temperature
print(df3["Connectivity"].mean())
print(df3["Connectivity"].median())
print(df3["Connectivity"].mode())
# Out:
# -0.04551785714285714
# 0.0
# 0    0.0
# Name: Connectivity, dtype: float64

# %%
#mean # median # mode 
print(df3["P_value"].mean())
print(df3["P_value"].median())
print(df3["P_value"].mode())
# Out:
# 0.708410304946
# 1.0
# 0    1.0
# Name: P_value, dtype: float64

# %%
#describe single column
print(df["id"].describe())
print(df["gen"].describe())
print(df["smile"].describe())
# Out:
# count     1177
# unique    1177
# top       AAAA
# freq         1
# Name: id, dtype: object
# count    1177.0
# mean        0.0
# std         0.0
# min         0.0
# 25%         0.0
# 50%         0.0
# 75%         0.0
# max         0.0
# Name: gen, dtype: float64
# count                                                  1177
# unique                                                 1164
# top       CC(C)(C)NC(=O)C1CN(Cc2cccnc2)CCN1CC(O)CC(Cc1cc...
# freq                                                      2
# Name: smile, dtype: object

# %%
print(df["source"].describe())
print(df["score"].describe())
# Out:
# count          1177
# unique            4
# top       generated
# freq           1102
# Name: source, dtype: object
# count    1.177000e+03
# mean     9.990000e+01
# std      1.421690e-14
# min      9.990000e+01
# 25%      9.990000e+01
# 50%      9.990000e+01
# 75%      9.990000e+01
# max      9.990000e+01
# Name: score, dtype: float64

# %%
# df2
print(df2["P_value"].describe())
print(df2["Connectivity"].describe())
# Out:
# count    1288.000000
# mean        0.705153
# std         0.385772
# min         0.003320
# 25%         0.311205
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: P_value, dtype: float64
# count    1288.000000
# mean       -0.045518
# std         0.157044
# min        -0.809330
# 25%        -0.199497
# 50%         0.000000
# 75%         0.000000
# max         0.723920
# Name: Connectivity, dtype: float64

# %%
# df2
print(df3["P_value"].describe())
print(df3["Connectivity"].describe())
# Out:
# count    1288.000000
# mean        0.708410
# std         0.384227
# min         0.003243
# 25%         0.312161
# 50%         1.000000
# 75%         1.000000
# max         1.000000
# Name: P_value, dtype: float64
# count    1288.000000
# mean       -0.045518
# std         0.157044
# min        -0.809330
# 25%        -0.199497
# 50%         0.000000
# 75%         0.000000
# max         0.723920
# Name: Connectivity, dtype: float64

# %%
#call dataset
data_1=pd.read_csv("master_results_table.csv")

# %%
data_2=pd.read_csv("mers_results.csv")

# %%
data_3=pd.read_csv("sars_results.csv")

# %%
data_1
# Out:
#         id  gen                                              smile     source  \
# 0     AAAA    0         COc1cccc(NC(=O)Cc2ccc(NC(=O)N3CCCC3)cc2)c1  generated
# 1     AAAB    0          C=CCNC(=O)CNc1cccc(C(=O)N(C)CCc2ccccc2)c1  generated
# 2     AAAC    0          CC(=O)Nc1ccc(S(=O)(=O)Nc2ccc(C)c(C)c2)cc1   training
# 3     AAAD    0      CCOC(=O)C1=C(C(=O)OCC)C(c2cccc(Cl)c2)NC(=O)N1  generated
# 4     AAAE    0  NC(=O)c1ccc(NC(=O)C(CC(=O)O)NC(=O)c2cc(-c3cccc...  generated
# ...    ...  ...                                                ...        ...
# 1172  ABTC    0  CCCC1(CCc2ccccc2)CC(O)=C(C(CC)c2cccc(NS(=O)(=O...     manual
# 1173  ABTD    0           O=C1Nc2ccc(Cl)cc2C(C#CC2CC2)(C(F)(F)F)O1     manual
# 1174  ABTE    0  CC(C)(C)NC(=O)C1CN(Cc2cccnc2)CCN1CC(O)CC(Cc1cc...     manual
# 1175  ABTF    0  CCOP(=O)(COc1ccc(CC(NC(=O)OC2COC3OCCC23)C(O)CN...     manual
# 1176  ABTG    0  COC(=O)NC(C(=O)NCCCCC(CO)N(CC(C)C)S(=O)(=O)c1c...     manual
#
#       score
# 0      99.9
# ...

# %%
data_2
# Out:
#                                    Unnamed: 0  Connectivity   P_value
# 0                               valproic acid     -0.376625  0.003320
# 1                                 flupentixol     -0.269090  0.003384
# 2                               syrosingopine     -0.318895  0.003397
# 3                             levomepromazine     -0.329905  0.003427
# 4                                 eucatropine     -0.288555  0.003468
# ...                                       ...           ...       ...
# 1283                                semustine      0.000000  1.000000
# 1284                                CP-944629      0.000000  1.000000
# 1285                               irinotecan      0.000000  1.000000
# 1286                                BCB000039      0.000000  1.000000
# 1287  11-deoxy-16,16-dimethylprostaglandin E2      0.000000  1.000000
#
# [1288 rows x 3 columns]

# %%
data_3
# Out:
#                                    Unnamed: 0  Connectivity   P_value
# 0                               valproic acid     -0.376625  0.003243
# 1                                   rifabutin     -0.340380  0.003250
# 2                             levomepromazine     -0.329905  0.003363
# 3                                   promazine     -0.338460  0.003409
# 4                               Prestwick-559     -0.332285  0.003454
# ...                                       ...           ...       ...
# 1283                                semustine      0.000000  1.000000
# 1284                                CP-944629      0.000000  1.000000
# 1285                               irinotecan      0.000000  1.000000
# 1286                                BCB000039      0.000000  1.000000
# 1287  11-deoxy-16,16-dimethylprostaglandin E2      0.000000  1.000000
#
# [1288 rows x 3 columns]

# %%
#value count
print(data_1["id"].value_counts())
# Out:
# id
# AAAA    1
# AAAB    1
# AAAC    1
# AAAD    1
# AAAE    1
#        ..
# ABTC    1
# ABTD    1
# ABTE    1
# ABTF    1
# ABTG    1
# Name: count, Length: 1177, dtype: int64

# %%
#value count
print(data_1["score"].value_counts())
# Out:
# score
# 99.9    1177
# Name: count, dtype: int64

# %%
#value count
print(data_1["gen"].value_counts())
# Out:
# gen
# 0    1177
# Name: count, dtype: int64

# %%
#value count
print(data_1["source"].value_counts())
# Out:
# source
# generated    1102
# training       49
# hiv            13
# manual         13
# Name: count, dtype: int64

# %%
print(data_2["Connectivity"].value_counts())
# Out:
# Connectivity
#  0.000000    720
# -0.237915      2
#  0.193460      2
# -0.171105      1
# -0.164335      1
#             ...
# -0.169540      1
# -0.176065      1
# -0.180495      1
#  0.143845      1
#  0.164355      1
# Name: count, Length: 567, dtype: int64

# %%
print(data_2["P_value"].value_counts())
# Out:
# P_value
# 1.000000    720
# 0.006971      2
# 0.125282      2
# 0.355245      2
# 0.946734      1
#            ...
# 0.981050      1
# 0.984919      1
# 0.994607      1
# 0.998939      1
# 0.003531      1
# Name: count, Length: 566, dtype: int64

# %%
#loc #label based indexing
data_1.loc[2]
# Out:
# id                                             AAAC
# gen                                               0
# smile     CC(=O)Nc1ccc(S(=O)(=O)Nc2ccc(C)c(C)c2)cc1
# source                                     training
# score                                          99.9
# Name: 2, dtype: object

# %% [markdown]
# data_1.loc[40:45]

# %%
data_2.loc[390]
# Out:
# Unnamed: 0      ornidazole
# Connectivity      -0.20975
# P_value           0.443139
# Name: 390, dtype: object

# %%
data_2.loc[1220]
# Out:
# Unnamed: 0      cyproterone
# Connectivity            0.0
# P_value                 1.0
# Name: 1220, dtype: object

# %%
data_2.loc[200:240]
# Out:
#                             Unnamed: 0  Connectivity   P_value
# 200                         anisomycin      0.284280  0.120189
# 201                         benfluorex      0.234015  0.120291
# 202                          esculetin     -0.226115  0.122767
# 203                      isometheptene      0.211265  0.123538
# 204                       orphenadrine     -0.224070  0.123906
# 205                      pheneticillin      0.216660  0.125282
# 206                     proxymetacaine     -0.234605  0.125282
# 207                      ioxaglic acid     -0.226985  0.125401
# 208                         clemastine     -0.249405  0.127937
# 209                      dexamethasone     -0.239820  0.129336
# 210        acetylsalicylsalicylic acid      0.227670  0.129546
# 211                     piperlongumine     -0.262800  0.129881
# 212                            betulin     -0.234695  0.130636
# 213                       CP-645525-01     -0.353025  0.130965
# ...

# %%
data_3.loc[70]
# Out:
# Unnamed: 0      benzamil
# Connectivity    -0.26397
# P_value           0.0311
# Name: 70, dtype: object

# %%
data_3.loc[150:155]
# Out:
#                           Unnamed: 0  Connectivity   P_value
# 150                        BCB000040     -0.247565  0.085560
# 151                           biotin      0.234925  0.086004
# 152              ipratropium bromide     -0.256885  0.086289
# 153                      alimemazine     -0.244060  0.086488
# 154                     clotrimazole     -0.262000  0.087364
# 155  15(S)-15-methylprostaglandin E2      0.255835  0.087811

# %%
#iloc indexing
data_1.iloc[60]
# Out:
# id                                   AACI
# gen                                     0
# smile     Fc1cccc(Nc2nnc(SCc3ccccc3)s2)c1
# source                          generated
# score                                99.9
# Name: 60, dtype: object

# %%
data_2.iloc[70:80]
# Out:
#           Unnamed: 0  Connectivity   P_value
# 70         diperodon       0.24430  0.032520
# 71      mitoxantrone      -0.28290  0.033291
# 72        ethaverine      -0.25181  0.033542
# 73     PHA-00846566E       0.33062  0.034893
# 74      benzthiazide       0.24571  0.035263
# 75      camptothecin      -0.29514  0.036333
# 76          monensin      -0.26986  0.037194
# 77  phenoxybenzamine      -0.33805  0.038069
# 78       verteporfin       0.33002  0.038529
# 79        nocodazole      -0.27160  0.038974

# %%
data_3.iloc[100:150]
# Out:
#                          Unnamed: 0  Connectivity   P_value
# 100                    enilconazole     -0.233260  0.051822
# 101                       AG-013608     -0.290095  0.052478
# 102                         5230742      0.262370  0.052760
# 103                       amoxapine     -0.255560  0.052895
# 104                     ellipticine     -0.287035  0.053223
# 105                      picotamide     -0.248775  0.053792
# 106                       glipizide     -0.239255  0.053963
# 107                       ionomycin     -0.261910  0.054032
# 108                 tranylcypromine     -0.236540  0.054458
# 109                      ciclopirox     -0.282845  0.055264
# 110                       verapamil     -0.273155  0.055545
# 111                   Prestwick-665     -0.249995  0.056219
# 112                      gliclazide     -0.241665  0.059229
# 113                    thiostrepton     -0.253930  0.059715
# 114                      moxisylyte      0.249095  0.060560
# ...

# %%
# data type
data_1.dtypes
# Out:
# id         object
# gen         int64
# smile      object
# source     object
# score     float64
# dtype: object

# %%
data_2.dtypes
# Out:
# Unnamed: 0       object
# Connectivity    float64
# P_value         float64
# dtype: object

# %%
data_3.dtypes
# Out:
# Unnamed: 0       object
# Connectivity    float64
# P_value         float64
# dtype: object

# %%
data_1.index
# Out:
# RangeIndex(start=0, stop=1177, step=1)

# %%
data_2.index
# Out:
# RangeIndex(start=0, stop=1288, step=1)

# %%
data_3.index
# Out:
# RangeIndex(start=0, stop=1288, step=1)

# %%
#tail
df.tail
# Out:
# <bound method NDFrame.tail of         id  gen                                              smile     source  \
# 0     AAAA    0         COc1cccc(NC(=O)Cc2ccc(NC(=O)N3CCCC3)cc2)c1  generated
# 1     AAAB    0          C=CCNC(=O)CNc1cccc(C(=O)N(C)CCc2ccccc2)c1  generated
# 2     AAAC    0          CC(=O)Nc1ccc(S(=O)(=O)Nc2ccc(C)c(C)c2)cc1   training
# 3     AAAD    0      CCOC(=O)C1=C(C(=O)OCC)C(c2cccc(Cl)c2)NC(=O)N1  generated
# 4     AAAE    0  NC(=O)c1ccc(NC(=O)C(CC(=O)O)NC(=O)c2cc(-c3cccc...  generated
# ...    ...  ...                                                ...        ...
# 1172  ABTC    0  CCCC1(CCc2ccccc2)CC(O)=C(C(CC)c2cccc(NS(=O)(=O...     manual
# 1173  ABTD    0           O=C1Nc2ccc(Cl)cc2C(C#CC2CC2)(C(F)(F)F)O1     manual
# 1174  ABTE    0  CC(C)(C)NC(=O)C1CN(Cc2cccnc2)CCN1CC(O)CC(Cc1cc...     manual
# 1175  ABTF    0  CCOP(=O)(COc1ccc(CC(NC(=O)OC2COC3OCCC23)C(O)CN...     manual
# 1176  ABTG    0  COC(=O)NC(C(=O)NCCCCC(CO)N(CC(C)C)S(=O)(=O)c1c...     manual
#
# ...

# %%
df2.tail
# Out:
# <bound method NDFrame.tail of                                    Unnamed: 0  Connectivity   P_value
# 0                               valproic acid     -0.376625  0.003320
# 1                                 flupentixol     -0.269090  0.003384
# 2                               syrosingopine     -0.318895  0.003397
# 3                             levomepromazine     -0.329905  0.003427
# 4                                 eucatropine     -0.288555  0.003468
# ...                                       ...           ...       ...
# 1283                                semustine      0.000000  1.000000
# 1284                                CP-944629      0.000000  1.000000
# 1285                               irinotecan      0.000000  1.000000
# 1286                                BCB000039      0.000000  1.000000
# 1287  11-deoxy-16,16-dimethylprostaglandin E2      0.000000  1.000000
#
# [1288 rows x 3 columns]>

# %%
df3.tail
# Out:
# <bound method NDFrame.tail of                                    Unnamed: 0  Connectivity   P_value
# 0                               valproic acid     -0.376625  0.003243
# 1                                   rifabutin     -0.340380  0.003250
# 2                             levomepromazine     -0.329905  0.003363
# 3                                   promazine     -0.338460  0.003409
# 4                               Prestwick-559     -0.332285  0.003454
# ...                                       ...           ...       ...
# 1283                                semustine      0.000000  1.000000
# 1284                                CP-944629      0.000000  1.000000
# 1285                               irinotecan      0.000000  1.000000
# 1286                                BCB000039      0.000000  1.000000
# 1287  11-deoxy-16,16-dimethylprostaglandin E2      0.000000  1.000000
#
# [1288 rows x 3 columns]>

# %%
# unique out of columns
df["id"].unique()
# Out:
# array(['AAAA', 'AAAB', 'AAAC', ..., 'ABTE', 'ABTF', 'ABTG'],
#       shape=(1177,), dtype=object)

# %%
df["score"].unique()
# Out:
# array([99.9])

# %%
df["source"].unique()
# Out:
# array(['generated', 'training', 'hiv', 'manual'], dtype=object)

# %%
df["smile"].unique()
# Out:
# array(['COc1cccc(NC(=O)Cc2ccc(NC(=O)N3CCCC3)cc2)c1',
#        'C=CCNC(=O)CNc1cccc(C(=O)N(C)CCc2ccccc2)c1',
#        'CC(=O)Nc1ccc(S(=O)(=O)Nc2ccc(C)c(C)c2)cc1', ...,
#        'CC(C)(C)NC(=O)C1CN(Cc2cccnc2)CCN1CC(O)CC(Cc1ccccc1)C(=O)NC1c2ccccc2CC1O',
#        'CCOP(=O)(COc1ccc(CC(NC(=O)OC2COC3OCCC23)C(O)CN(CC(C)C)S(=O)(=O)c2ccc(OC)cc2)cc1)OCC',
#        'COC(=O)NC(C(=O)NCCCCC(CO)N(CC(C)C)S(=O)(=O)c1ccc(N)cc1)C(c1ccccc1)c1ccccc1'],
#       shape=(1164,), dtype=object)

# %%
df["gen"].unique()
# Out:
# array([0])

# %%
df2["Connectivity"].unique()
# Out:
# array([-0.376625, -0.26909 , -0.318895, -0.329905, -0.288555, -0.37831 ,
#        -0.360245, -0.323295, -0.345995, -0.33846 , -0.321425, -0.34699 ,
#        -0.31996 , -0.287965, -0.375195, -0.35174 , -0.361685, -0.336405,
#        -0.350465, -0.297975, -0.365775, -0.358135, -0.282915, -0.31255 ,
#        -0.302   , -0.330245, -0.29838 , -0.30246 , -0.371125, -0.271445,
#         0.259215,  0.319895, -0.25581 , -0.31292 , -0.269645, -0.338605,
#        -0.34038 ,  0.29485 , -0.300325, -0.318135, -0.281245, -0.332285,
#        -0.288785,  0.26237 , -0.29511 , -0.274865, -0.267305,  0.27767 ,
#        -0.293095, -0.26397 , -0.301915, -0.325505, -0.288655, -0.301795,
#        -0.25603 , -0.274705, -0.26723 , -0.27253 , -0.28508 , -0.80933 ,
#        -0.291985, -0.255155, -0.261865, -0.2422  , -0.287995, -0.2769  ,
#         0.26068 , -0.273155, -0.286275,  0.2541  ,  0.2443  , -0.2829  ,
#        -0.25181 ,  0.33062 ,  0.24571 , -0.29514 , -0.26986 , -0.33805 ,
# ...

# %%
df2["P_value"].unique()
# Out:
# array([0.00331968, 0.00338357, 0.00339726, 0.00342658, 0.0034682 ,
#        0.00353087, 0.00355484, 0.00357524, 0.00358432, 0.00363285,
#        0.0037343 , 0.00389023, 0.00396885, 0.0042186 , 0.00450414,
#        0.00486791, 0.00550357, 0.00628477, 0.00643704, 0.00645932,
#        0.00664478, 0.00697121, 0.00697142, 0.00757783, 0.00895931,
#        0.00914021, 0.00915257, 0.00949567, 0.00980125, 0.01052681,
#        0.01165854, 0.01199206, 0.01328552, 0.01357921, 0.01416115,
#        0.01450921, 0.01463088, 0.01463118, 0.01520905, 0.01579844,
#        0.01631903, 0.01670527, 0.01700551, 0.01744755, 0.01788815,
#        0.01826373, 0.0196488 , 0.01981558, 0.02005149, 0.02089379,
#        0.02101087, 0.02143682, 0.02161217, 0.0219501 , 0.02234632,
#        0.02278351, 0.02366028, 0.023799  , 0.02386443, 0.02525801,
#        0.02753619, 0.02795078, 0.02799259, 0.02833159, 0.02851516,
#        0.02862323, 0.0286239 , 0.0289735 , 0.03181351, 0.03252018,
# ...

# %%
df3["Connectivity"].unique()
# Out:
# array([-0.376625, -0.34038 , -0.329905, -0.33846 , -0.332285, -0.345995,
#        -0.297975, -0.365775, -0.287965, -0.31292 , -0.34699 , -0.360245,
#        -0.31996 , -0.35174 , -0.358135, -0.301795, -0.80933 , -0.330245,
#        -0.288555, -0.318895, -0.300325,  0.319895, -0.323295, -0.28508 ,
#        -0.361685, -0.375195, -0.37831 , -0.336405, -0.281245, -0.321425,
#         0.29485 , -0.26909 , -0.31255 , -0.302   , -0.29838 , -0.301915,
#        -0.271445, -0.350465, -0.274865, -0.288785, -0.338605, -0.30246 ,
#         0.27767 , -0.293095, -0.288655, -0.371125, -0.28656 , -0.2769  ,
#        -0.25585 , -0.33805 ,  0.259215, -0.25581 , -0.318135, -0.29511 ,
#         0.377565, -0.269645, -0.291985, -0.274705, -0.2716  , -0.325505,
#        -0.282915, -0.26723 , -0.267305, -0.27012 ,  0.39239 , -0.25181 ,
#        -0.256375, -0.287995, -0.252995,  0.33002 , -0.26397 , -0.2897  ,
#        -0.286275, -0.27253 ,  0.23901 , -0.2829  , -0.255355, -0.265015,
# ...

# %%
df3["P_value"].unique()
# Out:
# array([0.00324343, 0.00324965, 0.00336306, 0.00340899, 0.00345374,
#        0.00348393, 0.003541  , 0.00364348, 0.00365301, 0.00369254,
#        0.00378577, 0.00380908, 0.00393532, 0.00408976, 0.00411894,
#        0.0042186 , 0.00628267, 0.00633598, 0.00642143, 0.00645941,
#        0.0066187 , 0.00664478, 0.00698725, 0.00718418, 0.00739317,
#        0.00740529, 0.00868336, 0.0088642 , 0.00906572, 0.00913692,
#        0.00920642, 0.00926711, 0.00969016, 0.01040167, 0.01071215,
#        0.01141925, 0.01181842, 0.01224836, 0.01274218, 0.01291129,
#        0.01342213, 0.01374026, 0.01433042, 0.01547963, 0.01619505,
#        0.01659326, 0.01660438, 0.01747866, 0.01751573, 0.01894865,
#        0.01898626, 0.01983623, 0.01988572, 0.01990638, 0.02143672,
#        0.02163578, 0.0227334 , 0.02313544, 0.02341258, 0.02345883,
#        0.02398731, 0.02454148, 0.02497331, 0.02566918, 0.02591131,
#        0.0260762 , 0.0265764 , 0.03073149, 0.03109995, 0.0317589 ,
# ...
